# %%
import pandas as pd
import numpy as np
import re
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
orders_rfm_11 = pd.read_csv('rfm-table_mark.csv', sep=';', index_col='Владелец карты', dtype={'RFMClass': np.object})
# orders_4_1 = pd.read_csv('Выгрузка по чекам 4_1.csv', header=None, encoding='utf-8', sep=';', low_memory=False)
# orders_4_2 = pd.read_csv('Выгрузка по чекам 4_1.csv', header=None, encoding='utf-8', sep=';', low_memory=False)

# %%
orders_rfm_11
# Out:
#                                  recency  frequency  monetary_value  \
# Владелец карты
# ,Вырупаева Ирина                     400          2         1065.00
# -                                    392          2          545.16
# ------                               384          1         1967.00
# ...                                  387          2         1467.00
# 01,02,1989                           434          1          306.00
# 206110014122                         440          1          169.00
# 206110036731                         432          2          943.00
# 2061100409801                        420          1          359.10
# 2061101716762                        389          4          357.00
# ? Артур Сулейманович                 441          1          187.00
# ? Варвара Витальевна                 424          2          742.06
# ? Вера Владимировна                  394          1          235.00
# ? Галина Васильевна                  383          2         1902.00
# ...

# %%
# orders_rfm_11['RFMClass'] = orders_rfm_11['RFMClass'].astype(str)

orders_rfm_11[orders_rfm_11['RFMClass']=='111'].sort_values('recency', ascending=True).head(300)
# Out:
#                                   recency  frequency  monetary_value  \
# Владелец карты
# юлия                                  383          9         4189.03
# Мулина Галина Васильевна              383          3         3173.00
# Мулинова Ирина Валерьевна             383          3         1841.08
# Муменова Юлия Николаевна              383          7         3327.00
# Второва Анна Юрьевна                  383          6         1836.00
# Всина Эльмира Александровна           383          3         1445.13
# Вотинова Василина Руслановна          383          6         3614.40
# Мясникова Александра Денисовна        383          3         1981.00
# Нагорная Елена Леонидовна             383          4         1150.00
# Надежда                               383        121        67245.97
# Надеждинская Юлия Валерьевна          383          4         1127.00
# Насибуллина Регина Ревалевна          383          4         1109.00
# ...

# %%
orders_rfm_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33501 entries, ,Вырупаева Ирина to яценко мария александровна
# Data columns (total 7 columns):
# recency           33501 non-null int64
# frequency         33501 non-null int64
# monetary_value    33501 non-null float64
# R_Quartile        33501 non-null int64
# F_Quartile        33501 non-null int64
# M_Quartile        33501 non-null int64
# RFMClass          33501 non-null object
# dtypes: float64(1), int64(5), object(1)
# memory usage: 2.0+ MB

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(orders_rfm_11)
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="ipynb_tmp\profile_6057973393.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
profile = pandas_profiling.ProfileReport(orders_rfm_11)
profile.to_file("working_RFM_profiling.html")

# %%
orders_rfm_11.index
# Out:
# Index([',Вырупаева Ирина', '-', '------', '...', '01,02,1989', '206110014122',
#        '206110036731', '2061100409801', '2061101716762',
#        '? Артур Сулейманович',
#        ...
#        'яковлева ольга александровна', 'яковлева татьяна федоровна',
#        'якушева юлия', 'ямщиков константин', 'яна',
#        'ярушева евгения николаевна', 'ярцева марина олеговна',
#        'яснецова татьяна евгеньевна', 'яценко Лариса Порфирьевна',
#        'яценко мария александровна'],
#       dtype='object', name='Владелец карты', length=33501)

# %%
orders_rfm_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33501 entries, ,Вырупаева Ирина to яценко мария александровна
# Data columns (total 7 columns):
# recency           33501 non-null int64
# frequency         33501 non-null int64
# monetary_value    33501 non-null float64
# R_Quartile        33501 non-null int64
# F_Quartile        33501 non-null int64
# M_Quartile        33501 non-null int64
# RFMClass          33501 non-null object
# dtypes: float64(1), int64(5), object(1)
# memory usage: 2.0+ MB
